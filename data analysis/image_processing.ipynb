# %%
import requests
from PIL import Image
from io import BytesIO

# %%
def download_img(url):
    response = requests.get(url)
    img = Image.open(BytesIO(response.content))
    return img

# %%
im1 = download_img('https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTxKvGY7rxZXh6wengzFmJadHFHOS2N_IN12g&usqp=CAU')
im1.save('image.png')

# %%
im2 = Image.open(r"C:\Users\niket\OneDrive\Pictures\Screenshots\Screenshot (15).png") # r is for raw string
im2.size
# Out:
# (1920, 1080)

# %%
im1
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=225x225>

# %%
im1.show()

# %%
im1.info
# Out:
# {'jfif': 257, 'jfif_version': (1, 1), 'jfif_unit': 0, 'jfif_density': (1, 1)}

# %%
im2.info
# Out:
# {'srgb': 0, 'gamma': 0.45455}

# %%
im1.mode # RGB
# Out:
# 'RGB'

# %%
# resize image
im1.resize((100,100))
# Out:
# <PIL.Image.Image image mode=RGB size=100x100>

# %%
im1.resize((3* im1.width, 3* im1.height))
# Out:
# <PIL.Image.Image image mode=RGB size=675x675>

# %%
im1.resize((im1.width // 3, im1.height // 3)).save('image3.png')

# %%
from PIL import ImageDraw, ImageFont

# %%
drawIm2 = ImageDraw.Draw(im2)
drawIm2.text((20,20), 'practical', fill='red', font=ImageFont.truetype('arial.ttf',100))
im2
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1920x1080>

# %%
im2.show()

# %%
im1.rotate(90)
# Out:
# <PIL.Image.Image image mode=RGB size=225x225>

# %%
im2.rotate(30, expand=True, fillcolor='white')
# Out:
# <PIL.Image.Image image mode=RGBA size=2204x1896>

# %%
#image flip
im1.transpose(Image.Transpose.FLIP_LEFT_RIGHT)
# Out:
# <PIL.Image.Image image mode=RGB size=225x225>

# %%
im1.transpose(Image.Transpose)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# d:\python\data analysis\image_processing.ipynb Cell 19 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/d%3A/python/data%20analysis/image_processing.ipynb#X24sZmlsZQ%3D%3D?line=0'>1</a> im1.transpose(Image.Transpose)
#
# File c:\Users\niket\miniconda3\lib\site-packages\PIL\Image.py:2689, in Image.transpose(self, method)
#    2675 """
#    2676 Transpose image (flip or rotate in 90 degree steps)
#    2677
#    (...)
#    2685 :returns: Returns a flipped or rotated copy of this image.
#    2686 """
#    2688 self.load()
# -> 2689 return self._new(self.im.transpose(method))
#
# TypeError: an integer is required (got type EnumMeta)
